# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = np.load('small_mnist_test_images.npy')
y = pd.DataFrame(np.load('small_mnist_test_labels.npy')).idxmax(axis = 1).values

Xbar = np.outer(np.ones(5000), np.mean(X, axis = 0))
Xtilde = np.subtract(X, Xbar)
#eigval, eigvec = np.linalg.eig(Xtilde.dot(Xtilde.T))
p1_idx, p2_idx = np.argsort(eigval)[::-1][:2]
p1 = eigvec[:, p1_idx]
p2 = eigvec[:, p2_idx]

plt.scatter(p1, p2, c = y, s = 1)
plt.title('Top 2 Principle Components')
plt.show()
# Out:
# C:\Users\caleb\Downloads\Anaconda\lib\site-packages\numpy\core\numeric.py:591: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
